# %% [markdown]
# ## Data Analysis of S&P500 stocks in Python -investment strategy during post-pandemic

# %%
import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 10000
    n = len(x)
    learning_rate = 0.08

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0 iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002 iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001 iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613 iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832 iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282 iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438 iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738 iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156 iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794 iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109 iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315 iteration 11
# ...

# %%
## Data Analysis of S&P500 stocks in Python -investment strategy during post-pandemic-

# %%
import os
import pandas as pd
import datetime as dt
from concurrent import futures
import matplotlib.pyplot as plt
import numpy as np
import yfinance as yf
import pandas_datareader.data as web
data_dir = "./data"
os.makedirs(data_dir, exist_ok=True)

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
first_table = tables[0]
second_table = tables[1]

# %%
df = first_table
print(df.shape)
df["Symbol"] = df["Symbol"].map(lambda x: x.replace(".", "-"))  # rename symbol to escape symbol error
sp500_tickers = list(df["Symbol"])
df.head()
# Out:
# (504, 9)
#   Symbol     Security SEC filings  GICS Sector         GICS Sub-Industry  \
# 0    MMM           3M     reports  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith     reports  Industrials         Building Products
# 2    ABT       Abbott     reports  Health Care     Health Care Equipment
# 3   ABBV       AbbVie     reports  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed     reports  Health Care     Health Care Equipment
#
#      Headquarters Location Date first added      CIK      Founded
# 0    Saint Paul, Minnesota       1976-08-09    66740         1902
# 1     Milwaukee, Wisconsin       2017-07-26    91142         1916
# 2  North Chicago, Illinois       1964-03-31     1800         1888
# 3  North Chicago, Illinois       2012-12-31  1551152  2013 (1888)
# 4   Danvers, Massachusetts       2018-05-31   815094         1981

# %% [markdown]
# The S&P 500 is supposed to consist of 500 stocks, but when you look at the resulting table, it contains 505 rows of data. Is this a mistake of some kind? No, this is not a mistake. The number of companies is 500, but the number of stocks may be higher than 500 if there are multiple classes of stocks for a single company based on voting rights or other factors (e.g., GOOG and GOOGL).

# %% [markdown]
# What sectors are the most common stocks in the S&P 500?
# In fact, stocks in the information technology sector account for the largest share(75 / 505). The next most common sector is industrials(73 stocks), followed by financial stocks(67 stocks) and healthcare(64 stocks)).

# %%
sectors = df["GICS Sector"].value_counts()
plt.bar(sectors.index, sectors.values)
plt.xticks(rotation=90)
plt.xlabel("sector")
plt.ylabel("number of stocks")
plt.show()

# %%
added_year = second_table["Date"]["Date"].map(lambda x: int(x[-4:]))
added_year = added_year.value_counts().sort_index()
plt.bar(added_year.index, added_year)
plt.xticks(rotation=30)
plt.xlabel("year")
plt.ylabel("number of replacesd tickers")
plt.show()

# %%
## Investment Strategy during Post-Pandemic

# %%
def download_stock(stock):
    try:
        print(stock)
        stock_df = web.DataReader(stock,'yahoo', start_time, end_time)
        stock_df['Name'] = stock
        output_name = f"{data_dir}/{stock}.csv"
        stock_df.to_csv(output_name)
    except:
        bad_names.append(stock)
        print('bad: %s' % (stock))
""" set the download window """
start_time = dt.datetime(2020, 1, 1)
end_time = dt.datetime(2022, 5, 30)
bad_names =[] #to keep track of failed queries
#set the maximum thread number
max_workers = 30
now = dt.datetime.now()
workers = min(max_workers, len(sp500_tickers)) #in case a smaller number of stocks than threads was passed in
with futures.ThreadPoolExecutor(workers) as executor:
    res = executor.map(download_stock, sp500_tickers)
""" Save failed queries to a text file to retry """
if len(bad_names) > 0:
    with open('failed_queries.txt','w') as outfile:
        for name in bad_names:
            outfile.write(name+'\n')
finish_time = dt.datetime.now()
duration = finish_time - now
minutes, seconds = divmod(duration.seconds, 60)
print(f'The threaded script took {minutes} minutes and {seconds} seconds to run.')
print(f"{len(bad_names)} stocks failed: ", bad_names)
# Out:
# MMMAOS
#
# ABT
# ABBV
# ABMD
# ACN
# ATVI
# ADMADBE
# ADP
#
# AAPAES
#
# AFL
# A
# AIG
# APD
# AKAM
# ALK
# ALB
# ARE
# ALGN
# ALLE
# LNT
# ALL
# GOOGL
# GOOG
# MO
# AMZN
# AMCR
# AMD
# AEEAAL
#
# AEPAXP
#
# AMT
# AWK
# AMP
# ABC
# AMEAMGN
#
# APH
# ADIANSS
#
# ANTM
# AON
# APA
# AAPL
# AMAT
# APTV
# ANET
# AIZ
# T
# ATO
# ADSK
# AZO
# AVB
# AVY
# BKR
# BALLBAC
#
# BBWI
# BAX
# BDX
# WRB
# BRK-B
# BBY
# BIO
# TECH
# BIIB
# BLK
# BK
# BA
# BKNG
# BWA
# BXP
# BSX
# BMY
# AVGO
# BR
# BRO
# BF-B
# CHRW
# CDNS
# CZR
# CPT
# CPBCOFCAH
# KMX
#
#
# CCL
# CARRCTLT
#
# CAT
# CBOE
# CBRE
# CDW
# CE
# CNC
# CNP
# CDAYCERN
#
# CF
# CRL
# SCHW
# CHTR
# CVX
# CMG
# CB
# CHD
# CI
# CINF
# CTAS
# CSCO
# C
# CFG
# CTXS
# CLX
# CMECMSKO
#
#
# CTSHCL
#
# CMCSA
# CMA
# CAG
# COP
# ED
# STZ
# CEG
# COO
# CPRT
# GLW
# CTVA
# COST
# CTRA
# CCI
# CSX
# CMI
# CVS
# DHI
# DHR
# DRI
# DVA
# DE
# DAL
# XRAY
# DVN
# DXCM
# FANG
# DLR
# DFS
# DISH
# DIS
# DG
# DLTR
# D
# DPZ
# DOV
# DOW
# DTE
# DUK
# DRE
# DD
# ...

# %%
lowest_dates = []
for x in sp500_tickers:
    historical_data = pd.read_csv(f"{data_dir}/{x}.csv", index_col="Date", parse_dates=True)
    lowest_date = historical_data["Close"].idxmin().strftime("%Y-%m-%d")
    lowest_dates.append(lowest_date)
    
date_counts = pd.DataFrame({"date": lowest_dates})["date"].value_counts()
date_counts.head()
# Out:
# 2020-03-23    259
# 2020-03-18     81
# 2020-03-20     36
# 2020-03-16     30
# 2020-03-12     19
# Name: date, dtype: int64

# %%
lowest_dates = []
for x in sp500_tickers:
    historical_data = pd.read_csv(f"{data_dir}/{x}.csv", index_col="Date", parse_dates=True)
    lowest_date = historical_data["Close"].idxmin().strftime("%Y-%m-%d")
    lowest_dates.append(lowest_date)
    
date_counts = pd.DataFrame({"date": lowest_dates})["date"].value_counts()
date_counts.head()
# Out:
# 2020-03-23    259
# 2020-03-18     81
# 2020-03-20     36
# 2020-03-16     30
# 2020-03-12     19
# Name: date, dtype: int64

# %%
size_list = []
for x in sp500_tickers:
    historical_data = pd.read_csv(f"{data_dir}/{x}.csv", index_col="Date", parse_dates=True)
    size_list.append(len(historical_data))
    
size_list = np.array(size_list)
latest_ipo_stocks = np.array(sp500_tickers)[np.where(size_list != size_list.max())[0]]
print("latest_ipo_stocks:", latest_ipo_stocks)
sp500_tickers = np.array(sp500_tickers)[np.where(size_list == size_list.max())[0]]
print("number of stocks after removal:", len(sp500_tickers))
df = df[df["Symbol"].isin(sp500_tickers)]  # removed the latest IPO stocks
# Out:
# latest_ipo_stocks: ['CARR' 'CEG' 'OGN' 'OTIS']
# number of stocks after removal: 500

# %%
def min_scale(x, axis=None):
    min = np.nanmin(x)
    result = ((x - min)/min)*100
    return result
# 5 GAFAM stocks example
fig, axes = plt.subplots(ncols=2, figsize=(14, 4))
for x in ["AAPL", "FB", "GOOG", "AMZN", "MSFT"]:
    historical_data = pd.read_csv(f"{data_dir}/{x}.csv")
    axes[0].plot(pd.to_datetime(historical_data["Date"]), historical_data["Close"].values, label=x)
    axes[1].plot(pd.to_datetime(historical_data["Date"]), min_scale(historical_data["Close"].values), label=x)
axes[0].tick_params(labelrotation=30)
axes[1].tick_params(labelrotation=30)
axes[0].set_ylabel("price($)")
axes[1].set_ylabel("performance(%)")
axes[0].legend(loc="upper left")
axes[1].legend(loc="upper left")
plt.show()

# %%
sector = sectors.index[10]  # from 0 to 10
for x in df[df["GICS Sector"]==sector]["Symbol"]:
    historical_data = pd.read_csv(f"{data_dir}/{x}.csv")
    plt.plot(pd.to_datetime(historical_data["Date"]), min_scale(historical_data["Close"].values),)
plt.title(f"{sector} sector")
plt.xticks(rotation=30)
plt.ylabel("performance(%)")
plt.show()

# %%
cm = plt.cm.get_cmap("tab20").colors
for i, sector in enumerate(sectors.index):
    sector_performance = []
    n_symbol = sectors[i]
    historical_data = [pd.read_csv(f"{data_dir}/{x}.csv",  index_col="Date", parse_dates=True)[["Close"]] for x in df[df["GICS Sector"]==sector]["Symbol"]]
    historical_data = pd.concat(historical_data, axis=1)
    sector_performance = historical_data.values  # np.ndarray
    sector_performance = np.apply_along_axis(min_scale, 0, sector_performance)
    sector_performance = sector_performance.T
    sector_performance = np.nanmean(sector_performance, axis=0)
    performance = int(sector_performance[-1])
    plt.plot(historical_data.index, sector_performance, label=f"{sector}(+{performance}%)", color=cm[i])
    
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=13)
plt.xticks(rotation=30)
plt.ylabel("performance(%)")
plt.show()

# %%
historical_data = [pd.read_csv(f"{data_dir}/{x}.csv",  index_col="Date", parse_dates=True)[["Close"]] for x in df["Symbol"]]
historical_data = pd.concat(historical_data, axis=1)
dates = historical_data.index
historical_data = historical_data.values  # np.ndarray
historical_data = np.apply_along_axis(min_scale, 0, historical_data)
historical_data = historical_data.T
print(f"Best performance at {dates.strftime('%Y-%m-%d')[-1]}")
idx = np.argsort(historical_data[:, -1])[::-1]
performances = np.sort(historical_data[:, -1])[::-1].astype(int)
top_k = 10
top_k_historical_data = historical_data[idx[:top_k]]
for i, x in enumerate(top_k_historical_data):
    symbol = df["Symbol"][idx[i]]
    plt.plot(dates, x, label=f"{symbol}(+{performances[i]}%)")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=13)
plt.xticks(rotation=30)
plt.ylabel("performance(%)")
plt.show()
# Out:
# Best performance at 2022-05-27
